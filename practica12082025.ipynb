# %% [markdown]
# <a href="https://colab.research.google.com/github/claudiopb/Curso-Fundamentos-de-desarrollo-de-software-en-un-entorno-virtual-en-la-nube/blob/main/practica12082025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Desarrollar software de sistemas informáticos.

# %% [markdown]
# ## Módulo I Desarrolla software de sistemas informáticos.
#
# #### Sub-módulo 3.
#
# **Implementar software de sistemas informáticos.**
#
# #### Actividad clave de la competencia laboral.
#
# **Ejecuta prueba de software en ambiente productivo.**
#
# #### Desarrollo de la competencia
# 1. Configura el entorno productivo
# para ejecución del software de
# instalación; atendiendo las
# instrucciones de su jefe inmediato,
# empleando una comunicación
# asertiva y colaborando con el
# equipo de trabajo.

# %% [markdown]
# Configurar el entorno de ejecución para:
#
# *  Visualizar una imagen 2d con formato de imagen (jpg, png)
# *  Cargar un archivo desde un medio de almacenamiento persistente.

# %% [markdown]
# <p>
# <img src="https://drive.google.com/uc?id=1LURfMlsdhMObUx_29pG7c6vB60jwjo-2"
# height="380px" width="350px"
# alt="Tipos de datos."/>
# </p>
#
# <p>
# <img src="https://drive.google.com/uc?id=1487YdLJDXXP68TK2Hux94n90Ba4jam-N"
# height="380px" width="350px"
# alt="Tipos de datos."/>
# </p>
#
# https://drive.google.com/file/d/1487YdLJDXXP68TK2Hux94n90Ba4jam-N/view?usp=sharing
#
# https://drive.google.com/uc?id=1487YdLJDXXP68TK2Hux94n90Ba4jam-N

# %% [markdown]
# Para insertar una imagen almacenada en Google Drive en una celda de Colab usando HTML, no puedes usar la ruta de archivo local como en el caso de Python o Markdown. En su lugar, debes usar el ID del archivo y crear un enlace público para que la imagen sea visible.
#
# Sigue estos pasos:
#
# Haz la imagen pública:
#
# En Google Drive, haz clic derecho en la imagen que quieres insertar.
#
# Selecciona "Compartir" y luego "Compartir" de nuevo.
#
# Cambia la configuración de acceso de "Restringido" a "Cualquier persona con el enlace".
#
# Haz clic en "Copiar enlace" y luego en "Listo".
#
# Extrae el ID del archivo:
#
# El enlace que copiaste se verá similar a https://drive.google.com/file/d/1a2b3c4d5e6f7g8h9i0j1k2l3m4n5o6p/view?usp=sharing.
#
# El ID de tu archivo es la parte de la URL que está entre /d/ y /view. En este ejemplo, el ID sería 1a2b3c4d5e6f7g8h9i0j1k2l3m4n5o6p.
#
# Crea el código HTML:
#
# En una celda de texto de Colab, usa la siguiente estructura HTML:
#
# HTML
#
# <img src="https://drive.google.com/uc?id=TU_ID_DE_IMAGEN" />
# Reemplaza TU_ID_DE_IMAGEN con el ID que obtuviste en el paso anterior. Por ejemplo:
#
# HTML
#
# <img src="https://drive.google.com/uc?id=1a2b3c4d5e6f7g8h9i0j1k2l3m4n5o6p" />
# Cuando ejecutes la celda, la imagen se mostrará.

# %%
"""testEjecución.py    Muestra la  """

print("Hola Mundo...!")
# Out:
# Hola Mundo...!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import pandas library
import pandas as pd

# Read the file into gross
#csvFile = "/content/drive/MyDrive/IntroduccionEstadisticaPython/InteractivePYthonNoteBook/DisneyMoviesBoxOfficeSuccess/disney_movies_total_gross.csv"
csvFile = "/content/drive/MyDrive/Funddesoftwarevirtual/Archivos/disney_movies_total_gross.csv"
gross = pd.read_csv(csvFile,parse_dates=["release_date"])

# Print out gross
gross.head(50)
# Out:
#                                movie_title release_date      genre  \
# 0          Snow White and the Seven Dwarfs   1937-12-21    Musical
# 1                                Pinocchio   1940-02-09  Adventure
# 2                                 Fantasia   1940-11-13    Musical
# 3                        Song of the South   1946-11-12  Adventure
# 4                               Cinderella   1950-02-15      Drama
# 5             20,000 Leagues Under the Sea   1954-12-23  Adventure
# 6                       Lady and the Tramp   1955-06-22      Drama
# 7                          Sleeping Beauty   1959-01-29      Drama
# 8                           101 Dalmatians   1961-01-25     Comedy
# 9              The Absent Minded Professor   1961-03-16     Comedy
# 10                        Babes in Toyland   1961-12-14    Musical
# 11                             Bon Voyage!   1962-05-17     Comedy
# 12                  The Sword in the Stone   1963-12-25  Adventure
# ...

# %%
gross.tail(10)
# Out:
#                          movie_title release_date      genre mpaa_rating  \
# 569       Captain America: Civil War   2016-05-06     Action       PG-13
# 570  Alice Through the Looking Glass   2016-05-27  Adventure          PG
# 571                     Finding Dory   2016-06-17  Adventure          PG
# 572                          The BFG   2016-07-01  Adventure          PG
# 573                    Pete’s Dragon   2016-08-12  Adventure          PG
# 574         The Light Between Oceans   2016-09-02      Drama       PG-13
# 575                   Queen of Katwe   2016-09-23      Drama          PG
# 576                   Doctor Strange   2016-11-04  Adventure       PG-13
# 577                            Moana   2016-11-23  Adventure          PG
# 578     Rogue One: A Star Wars Story   2016-12-16  Adventure       PG-13
#
#      total_gross  inflation_adjusted_gross
# 569    408084349                 408084349
# 570     77042381                  77042381
# ...
